# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_path = Path("../Starter_Code/Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_path)
whale_df.head()
# Out:
#          Date  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 0  2015-03-02                        NaN                 NaN
# 1  2015-03-03                  -0.001266           -0.004981
# 2  2015-03-04                   0.002230            0.003241
# 3  2015-03-05                   0.004016            0.004076
# 4  2015-03-06                  -0.007905           -0.003574
#
#    TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# 0                          NaN                     NaN
# 1                    -0.000496               -0.006569
# 2                    -0.002534                0.004213
# 3                     0.002355                0.006726
# 4                    -0.008481               -0.013098

# %%
# Count nulls
whale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         1060 non-null   object
#  1   SOROS FUND MANAGEMENT LLC    1059 non-null   float64
#  2   PAULSON & CO.INC.            1059 non-null   float64
#  3   TIGER GLOBAL MANAGEMENT LLC  1059 non-null   float64
#  4   BERKSHIRE HATHAWAY INC       1059 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 41.5+ KB

# %%
# Drop nulls
whale_df=whale_df.dropna()

#Set DateTimeIndex
whale_df.set_index(pd.to_datetime(whale_df['Date'] , infer_datetime_format = True) , inplace = True)
whale_df=whale_df.drop(columns='Date')
whale_df.sort_index(inplace=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_path = Path("../Starter_Code/Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_path)
algo_df.head()
# Out:
#          Date    Algo 1  Algo 2
# 0  2014-05-28  0.001745     NaN
# 1  2014-05-29  0.003978     NaN
# 2  2014-05-30  0.004464     NaN
# 3  2014-06-02  0.005692     NaN
# 4  2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isna().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df=algo_df.dropna()
# Set datetimeindex
algo_df.set_index(pd.to_datetime(algo_df['Date'] , infer_datetime_format = True) , inplace = True)
algo_df.drop(columns='Date', inplace=True)
algo_df.sort_index(inplace=True)
algo_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_path = Path("../Starter_Code/Resources/sp_tsx_history.csv")
sp_tsx_df = pd.read_csv(sp_tsx_path)
sp_tsx_df.head()
# Out:
#          Date       Close
# 0  1-Oct-2012  $12,370.19
# 1  2-Oct-2012  $12,391.23
# 2  3-Oct-2012  $12,359.47
# 3  4-Oct-2012  $12,447.68
# 4  5-Oct-2012  $12,418.99

# %%
# Check Data Types
sp_tsx_df.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_tsx_df.set_index(pd.to_datetime(sp_tsx_df['Date'] , infer_datetime_format = True) , inplace = True)
sp_tsx_df.drop(columns=['Date'],inplace=True)
sp_tsx_df.sort_index(inplace=True)
sp_tsx_df['Close']=sp_tsx_df['Close'].str.replace('$','')
sp_tsx_df['Close']=pd.to_numeric(sp_tsx_df['Close'].str.replace(',',''))
sp_tsx_df.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
# Calculate Daily Returns

sp_tsx_returns=sp_tsx_df.pct_change()
sp_tsx_returns=sp_tsx_returns.dropna()
sp_tsx_returns.plot(figsize=(20,5),title="Daily Returns of SP_TSX")
# Out:
# <AxesSubplot:title={'center':'Daily Returns of SP_TSX'}, xlabel='Date'>

# %%
# Drop nulls
sp_tsx_returns=sp_tsx_returns.dropna()
sp_tsx_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_tsx_returns=sp_tsx_returns.rename(columns={'Close':'sp_tsx'})
sp_tsx_returns.head()
# Out:
#               sp_tsx
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
all_df=pd.concat([ algo_df, whale_df,sp_tsx_returns], axis = "columns", join = "inner")
all_df.head()
# Out:
#               Algo 1    Algo 2  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03 -0.001942 -0.000949                  -0.001266           -0.004981
# 2015-03-04 -0.008589  0.002416                   0.002230            0.003241
# 2015-03-05 -0.000955  0.004323                   0.004016            0.004076
# 2015-03-06 -0.004957 -0.011460                  -0.007905           -0.003574
# 2015-03-09 -0.005447  0.001303                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    sp_tsx
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.008530
# 2015-03-04                    -0.002534                0.004213 -0.003371
# 2015-03-05                     0.002355                0.006726  0.001344
# 2015-03-06                    -0.008481               -0.013098 -0.009972
# 2015-03-09                     0.005843               -0.001652 -0.006555

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_df.plot(figsize=(20,5),title="Daily Returns of all prtofolios")
# Out:
# <AxesSubplot:title={'center':'Daily Returns of all prtofolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
all_cum_ret = (1 + all_df).cumprod(axis=0)
# Plot cumulative returns
all_cum_ret.plot(figsize=(20,5),title="Cumulative Returns of all prtofolios")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of all prtofolios'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P TSX 60
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
all_df.plot.box(figsize=(20,5),title="Portofolio Risk")
# Out:
# <AxesSubplot:title={'center':'Portofolio Risk'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_std = all_df.std()
all_std.head(20)
# Out:
# Algo 1                         0.007589
# Algo 2                         0.008326
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# sp_tsx                         0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
# Determine which portfolios are riskier than the S&P TSX 60
all_std.loc[all_std.iloc[:]>all_std.iloc[-1]]
# Out:
# Algo 1                         0.007589
# Algo 2                         0.008326
# SOROS FUND MANAGEMENT LLC      0.007828
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std=all_std*np.sqrt(252)
annualized_std.head()
# Out:
# Algo 1                         0.120470
# Algo 2                         0.132177
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for the S&P TSX 60 using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60
# 3. Calculate and plot a 60-day Beta for Berkshire Hathaway Inc compared to the S&P 60 TSX

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_std_roll21=all_cum_ret.rolling(window=21).std()
# Plot the rolling standard deviation
all_std_roll21.plot(figsize=[20,5], title = "Standard deviations all portofolios")
# Out:
# <AxesSubplot:title={'center':'Standard deviations all portofolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation=all_df.corr()
# Display de correlation matrix
correlation
# Out:
#                                Algo 1    Algo 2  SOROS FUND MANAGEMENT LLC  \
# Algo 1                       1.000000  0.285455                   0.313795
# Algo 2                       0.285455  1.000000                   0.826667
# SOROS FUND MANAGEMENT LLC    0.313795  0.826667                   1.000000
# PAULSON & CO.INC.            0.266363  0.674015                   0.697076
# TIGER GLOBAL MANAGEMENT LLC  0.161236  0.506689                   0.560964
# BERKSHIRE HATHAWAY INC       0.289378  0.684609                   0.750181
# sp_tsx                       0.310276  0.737370                   0.673930
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Algo 1                                 0.266363                     0.161236
# Algo 2                                 0.674015                     0.506689
# SOROS FUND MANAGEMENT LLC              0.697076                     0.560964
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
cov_algo1=all_df['Algo 1'].cov(all_df['sp_tsx'])
# Calculate variance of S&P TSX
var_sp_tsx=all_df['sp_tsx'].var()
# Computing beta
beta_algo1=cov_algo1/all_df['Algo 1'].var()
# Plot beta trend
rolling21_cov=all_df['Algo 1'].rolling(21).cov(all_df['sp_tsx'])
rolling21_var=all_df['Algo 1'].rolling(21).var()
rolling21_beta=rolling21_cov/rolling21_var
rolling21_beta.plot(figsize=[20,5], title= "Algo 1 beta on a 21 day window")
# Out:
# <AxesSubplot:title={'center':'Algo 1 beta on a 21 day window'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window
ewm_algo1_cov=all_df['Algo 1'].ewm(halflife=21).cov(all_df['sp_tsx'])
ewm_algo1_var=all_df['Algo 1'].ewm(halflife=21).var()
ewm_algo1_beta=ewm_algo1_cov/ewm_algo1_var
ewm_algo1_beta.plot(figsize=[20,5],title= "Algo 1 beta calculated using ewm")
# Out:
# <AxesSubplot:title={'center':'Algo 1 beta calculated using ewm'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (all_df.mean()*252)/(all_df.std()*np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar",title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# Algo 1 outperforms the SP_TSX60 and the whales portofolios. Algo 1 outperforms the SP_TSX60 and most of the whale portofolio with exception of the Berkshire Hathaway INC.

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P TSX 60 index.
#
# * `SHOP` - [Shopify Inc](https://en.wikipedia.org/wiki/Shopify)
#
# * `OTEX` - [Open Text Corporation](https://en.wikipedia.org/wiki/OpenText)
#
# * `L` - [Loblaw Companies Limited](https://en.wikipedia.org/wiki/Loblaw_Companies)

# %%
# Reading data from 1st stock
shop_path = Path("../Starter_Code/Resources/shop_historical.csv")
shop_df = pd.read_csv(shop_path, index_col="Date", parse_dates=True, infer_datetime_format=True).rename(columns={"Close":"SHOP"}).drop(columns=['Symbol'])
shop_df.head()
# Out:
#               SHOP
# Date
# 2018-01-02  132.06
# 2018-01-03  135.15
# 2018-01-04  137.46
# 2018-01-05  137.26
# 2018-01-08  139.51

# %%
# Reading data from 2nd stock
otex_path = Path("../Starter_Code/Resources/otex_historical.csv")
otex_df = pd.read_csv(otex_path, index_col="Date", parse_dates=True, infer_datetime_format=True).rename(columns={"Close":"OTEX"}).drop(columns=['Symbol'])
otex_df.head()
# Out:
#              OTEX
# Date
# 2018-01-02  43.58
# 2018-01-03  43.07
# 2018-01-04  42.91
# 2018-01-05  42.57
# 2018-01-08  42.16

# %%
# Reading data from 3rd stock
l_path = Path("../Starter_Code/Resources/l_historical.csv")
l_df = pd.read_csv(l_path, index_col="Date", parse_dates=True, infer_datetime_format=True).rename(columns={"Close":"L"}).drop(columns=['Symbol'])
l_df.head()
# Out:
#                 L
# Date
# 2018-01-02  57.99
# 2018-01-03  57.41
# 2018-01-04  57.42
# 2018-01-05  57.42
# 2018-01-08  56.86

# %%
# Combine all stocks in a single DataFrame
all3_df=pd.concat([shop_df,otex_df,l_df],axis='columns',join='inner')
all3_df.info()
all3_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 501 entries, 2018-01-02 to 2019-12-30
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SHOP    501 non-null    float64
#  1   OTEX    501 non-null    float64
#  2   L       501 non-null    float64
# dtypes: float64(3)
# memory usage: 15.7 KB
#               SHOP   OTEX      L
# Date
# 2018-01-02  132.06  43.58  57.99
# 2018-01-03  135.15  43.07  57.41
# 2018-01-04  137.46  42.91  57.42
# 2018-01-05  137.26  42.57  57.42
# 2018-01-08  139.51  42.16  56.86

# %%
# Reset Date index
# See kernels 107, 108, 109

# %%
# Reorganize portfolio data by having a column per symbol
# See kernels 107, 108, 109

# %%
# Calculate daily returns
all3_daily_returns=all3_df.pct_change()
# Drop NAs
all3_daily_returns.dropna(inplace=True)
# Display sample data
all3_daily_returns.head()
# Out:
#                 SHOP      OTEX         L
# Date
# 2018-01-03  0.023398 -0.011703 -0.010002
# 2018-01-04  0.017092 -0.003715  0.000174
# 2018-01-05 -0.001455 -0.007924  0.000000
# 2018-01-08  0.016392 -0.009631 -0.009753
# 2018-01-09 -0.011254 -0.000712  0.008969

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]
# Calculate portfolio return
my_portofolio=(all3_daily_returns*weights).sum(axis=1)
# Display sample data
my_portofolio.head()
# Out:
# Date
# 2018-01-03    0.000565
# 2018-01-04    0.004517
# 2018-01-05   -0.003126
# 2018-01-08   -0.000997
# 2018-01-09   -0.000999
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_portofolios=pd.concat([my_portofolio,all_df],axis='columns',join='inner').rename(columns={0:"MyPortofolio"})
all_portofolios.head()
# Out:
#             MyPortofolio    Algo 1    Algo 2  SOROS FUND MANAGEMENT LLC  \
# Date
# 2018-01-03      0.000565 -0.000890  0.008175                   0.004658
# 2018-01-04      0.004517 -0.000914  0.004294                  -0.000914
# 2018-01-05     -0.003126 -0.003839  0.006405                   0.004072
# 2018-01-08     -0.000997  0.001653  0.000658                   0.004473
# 2018-01-09     -0.000999 -0.001004 -0.002091                  -0.001028
#
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Date
# 2018-01-03            0.000027                     0.001979
# 2018-01-04            0.004196                     0.010743
# 2018-01-05            0.000823                     0.000737
# 2018-01-08           -0.003739                     0.005085
# 2018-01-09            0.000872                     0.001789
#
#             BERKSHIRE HATHAWAY INC    sp_tsx
# Date
# 2018-01-03                0.005676  0.003774
# 2018-01-04                0.004065  0.002528
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_portofolios.dropna(inplace=True)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std_all_port=all_portofolios.std()*np.sqrt(252)
annualized_std_all_port
# Out:
# MyPortofolio                   0.224346
# Algo 1                         0.120028
# Algo 2                         0.137664
# SOROS FUND MANAGEMENT LLC      0.145675
# PAULSON & CO.INC.              0.114343
# TIGER GLOBAL MANAGEMENT LLC    0.219833
# BERKSHIRE HATHAWAY INC         0.227445
# sp_tsx                         0.099121
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling21_std_all=all_portofolios.rolling(window=21).std()
# Plot rolling standard deviation
rolling21_std_all.plot(figsize=[20,5],title= "Rolling std. 21-day window")
# Out:
# <AxesSubplot:title={'center':'Rolling std. 21-day window'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_all=all_portofolios.corr()
sns.heatmap(correlation_all, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
cov_my_port=all_portofolios['MyPortofolio'].cov(all_df['sp_tsx'])
# Calculate variance of S&P TSX
var_my_port=all_portofolios['MyPortofolio'].var()
# Computing beta
beta_my_port=cov_my_port/var_my_port

my_port_rolling21_cov=all_portofolios['MyPortofolio'].rolling(21).cov(all_df['sp_tsx'])
my_port_rolling21_var=all_portofolios['MyPortofolio'].rolling(21).var()
my_port_rolling21_beta=my_port_rolling21_cov/my_port_rolling21_var
my_port_rolling21_beta.plot(figsize=[20,5], title= "My portofolio beta on a 21 day window")
# Out:
# <AxesSubplot:title={'center':'My portofolio beta on a 21 day window'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios
sharpe_ratios_all = (all_portofolios.mean()*252)/(all_portofolios.std()*np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_all.plot(kind="bar",title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# My protofolio is almost as good as Algo 1 which has the highest sarpe ratio.
